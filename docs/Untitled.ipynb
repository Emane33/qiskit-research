# %%
from qiskit_research.protein_folding.interactions.random_interaction import (
    RandomInteraction,
)
from qiskit_research.protein_folding.interactions.miyazawa_jernigan_interaction import (
    MiyazawaJerniganInteraction,
)
from qiskit_research.protein_folding.peptide.peptide import Peptide
from qiskit_research.protein_folding.protein_folding_problem import (
    ProteinFoldingProblem,
)

from qiskit_research.protein_folding.penalty_parameters import PenaltyParameters
from qiskit.utils import algorithm_globals, QuantumInstance

algorithm_globals.random_seed = 23
main_chain = "APRLRFY"
side_chains = ["" , "A", "P", "R", "L", "F",""]
side_chain_1 = ["" , "A", "P", "R", "L", "F",""]
side_chain_2 = ["" , "A", "P", "R", "L", "F",""]
side_chain_3 = ["" , "A", "P", "R", "L", "F",""]
result = []
for i in range(len(side_chains)):
    result.append(side_chains[i] + side_chain_1[i] + side_chain_2[i] + side_chain_3[i])

mj_interaction = MiyazawaJerniganInteraction()
penalty_back = 10
penalty_chiral = 10
penalty_1 = 10

penalty_terms = PenaltyParameters(penalty_chiral, penalty_back, penalty_1)
peptide = Peptide(main_chain, result)

protein_folding_problem = ProteinFoldingProblem(peptide, mj_interaction, penalty_terms)
qubit_op = protein_folding_problem.qubit_op()
print(qubit_op)
# Out:
# 4075.415 * IIIIIIIIIIIIIIIIIIIIIIII
# - 157.5 * IIIIIIIIIIIIIIZIIIIIIIII
# - 77.5 * IIIIIIIIIIIIIIIZIIIIIIII
# - 82.5 * IIIIIIIIIIIIIIZZIIIIIIII
# + 360.625 * IIIIIIIIIIIIIIIIIIIIIIIZ
# + 0.625 * IIIIIIIIIIIIIIIIIIIIIIZI
# + 0.625 * IIIIIIIIIIIIIIIIIIIIIIZZ
# + 0.625 * IIIIIIIIIIIIZIIIIIIIIIZI
# - 1.875 * IIIIIIIIIIIIZIIIIIIIIIZZ
# + 85.625 * IIIIIIIIIIIIZIIIIIIIIIII
# + 0.625 * IIIIIIIIIIIIZIIIIIIIIIIZ
# - 84.375 * IIIIIIIIIIIIIZIIIIIIIIIZ
# + 0.625 * IIIIIIIIIIIIIZIIIIIIIIII
# + 0.625 * IIIIIIIIIIIIIZIIIIIIIIZZ
# - 1.875 * IIIIIIIIIIIIIZIIIIIIIIZI
# + 0.625 * IIIIIIIIIIIIZZIIIIIIIIZZ
# + 0.625 * IIIIIIIIIIIIZZIIIIIIIIZI
# + 83.125 * IIIIIIIIIIIIZZIIIIIIIIIZ
# + 0.625 * IIIIIIIIIIIIZZIIIIIIIIII
# + 0.625 * IIIIIIIIIIIIIIIIIIIIZIZI
# - 516.875 * IIIIIIIIIIIIIIIIIIIIIZIZ
# + 0.625 * IIIIIIIIIIIIIIIIIIIIZZZZ
# + 0.625 * IIIIIIIIIIZIIIIIIIIIZIII
# + 0.625 * IIIIIIIIIIZIIIIIIIIIIIZI
# + 0.625 * IIIIIIIIIIZIIIIIIIIIZZIZ
# - 1.875 * IIIIIIIIIIZIIIIIIIIIIZZZ
# + 0.625 * IIIIIIIIIIIZIIIIIIIIIZII
# - 1.875 * IIIIIIIIIIIZIIIIIIIIZZZI
# + 0.625 * IIIIIIIIIIIZIIIIIIIIIIIZ
# + 0.625 * IIIIIIIIIIIZIIIIIIIIZIZZ
# + 0.625 * IIIIIIIIIIZZIIIIIIIIZZII
# + 0.625 * IIIIIIIIIIZZIIIIIIIIIZZI
# - 1.875 * IIIIIIIIIIZZIIIIIIIIZIIZ
# + 0.625 * IIIIIIIIIIZZIIIIIIIIIIZZ
# - 439.375 * IIIIIIIIIIIIIIIIIIIZIZII
# - 439.375 * IIIIIIIIIIIIIIIIIIZIZIII
# - 439.375 * IIIIIIIIIIIIIIIIIIZZZZII
# + 0.625 * IIIIIIIIZIIIIIIIIIZIIIII
# - 1.875 * IIIIIIIIZIIIIIIIIIZZIZII
# - 84.375 * IIIIIIIIZIIIIIIIIIIIZIII
# + 0.625 * IIIIIIIIZIIIIIIIIIIZZZII
# + 0.625 * IIIIIIIIIZIIIIIIIIIZIIII
# - 84.375 * IIIIIIIIIZIIIIIIIIIIIZII
# + 0.625 * IIIIIIIIIZIIIIIIIIZZZIII
# - 1.875 * IIIIIIIIIZIIIIIIIIZIZZII
# + 0.625 * IIIIIIIIZZIIIIIIIIZZIIII
# + 0.625 * IIIIIIIIZZIIIIIIIIZIIZII
# - 1.875 * IIIIIIIIZZIIIIIIIIIZZIII
# - 84.375 * IIIIIIIIZZIIIIIIIIIIZZII
# - 179.375 * IIIIIIIIIIIIIIIIZIZIIIII
# - 179.375 * IIIIIIIIIIIIIIIIIZIZIIII
# - 179.375 * IIIIIIIIIIIIIIIIZZZZIIII
# + 0.625 * IIIIIIZIIIIIIIIIZIIIIIII
# - 79.375 * IIIIIIZIIIIIIIIIIIZIIIII
# + 0.625 * IIIIIIZIIIIIIIIIZZIZIIII
# - 1.875 * IIIIIIZIIIIIIIIIIZZZIIII
# + 0.625 * IIIIIIIZIIIIIIIIIZIIIIII
# - 1.875 * IIIIIIIZIIIIIIIIZZZIIIII
# - 79.375 * IIIIIIIZIIIIIIIIIIIZIIII
# + 0.625 * IIIIIIIZIIIIIIIIZIZZIIII
# + 0.625 * IIIIIIZZIIIIIIIIZZIIIIII
# + 0.625 * IIIIIIZZIIIIIIIIIZZIIIII
# - 1.875 * IIIIIIZZIIIIIIIIZIIZIIII
# - 79.375 * IIIIIIZZIIIIIIIIIIZZIIII
# + 1137.5 * IIIIIIIIIIIIIIIIIIIIZIII
# + 620.0 * IIIIIIIIIIIIIIIIIIIIZZII
# - 900.0 * IIIIIIIIIIIIIIIIIIZIIIII
# - 460.0 * IIIIIIIIIIIIIIIIIIZZIIII
# + 517.5 * IIIIIIIIIIIIIIIIIIIIZZIZ
# + 440.0 * IIIIIIIIIIIIIIIIIIIZIIIZ
# - 440.0 * IIIIIIIIIIIIIIIIIIZZIIIZ
# - 904.2875 * IZIIIIIIIIIIIIIIIIIIIIII
# - 295.0 * IZIIIIIIIIIIIIIIIIIIZIII
# - 197.5 * IZIIIIIIIIIIIIIIIIIIZZII
# + 302.5 * IZIIIIIIIIIIIIIIIIZIIIII
# + 202.5 * IZIIIIIIIIIIIIIIIIZZIIII
# + 100.0 * IZIIIIIIIIIIIIIIIIZIZIII
# + 100.0 * IZIIIIIIIIIIIIIIIIIZIZII
# + 100.0 * IZIIIIIIIIIIIIIIIIZZZZII
# - 200.0 * IZIIIIIIIIIIIIIIIIIIIIIZ
# + 97.5 * IZIIIIIIIIIIIIIIIIIIIZIZ
# - 97.5 * IZIIIIIIIIIIIIIIIIIIZZIZ
# - 100.0 * IZIIIIIIIIIIIIIIIIIZIIIZ
# + 100.0 * IZIIIIIIIIIIIIIIIIZZIIIZ
# + 260.0 * IIIIIIIIIIIIIIIIIIIIIZII
# - 265.0 * IIIIIIIIIIIIIIIIIIIZIIII
# + 2.5 * IZIIIIIIIIIIIIIIIIIIIZII
# - 2.5 * IZIIIIIIIIIIIIIIIIIZIIII
# + 272.5 * IIIIIIIIIIIIIIIIZIIIIIII
# + 92.5 * IIIIIIIIIIIIIIIIZZIIIIII
# + 180.0 * IIIIIIIIIIIIIIIIZIIIZIII
# + 180.0 * IIIIIIIIIIIIIIIIIZIIIZII
# + 180.0 * IIIIIIIIIIIIIIIIZZIIZZII
# - 180.0 * IIIIIIIIIIIIIIIIIZIIIIIZ
# + 180.0 * IIIIIIIIIIIIIIIIZZIIIIIZ
# + 7.5 * IZIIIIIIIIIIIIIIZIIIIIII
# + 5.0 * IZIIIIIIIIIIIIIIZZIIIIII
# + 2.5 * IZIIIIIIIIIIIIIIZIIIZIII
# + 2.5 * IZIIIIIIIIIIIIIIIZIIIZII
# + 2.5 * IZIIIIIIIIIIIIIIZZIIZZII
# - 2.5 * IZIIIIIIIIIIIIIIZIZIIIII
# - 2.5 * IZIIIIIIIIIIIIIIIZIZIIII
# - 2.5 * IZIIIIIIIIIIIIIIZZZZIIII
# - 2.5 * IZIIIIIIIIIIIIIIIZIIIIIZ
# + 2.5 * IZIIIIIIIIIIIIIIZZIIIIIZ
# + 102.5 * IIIIIIIIIIIIIIIIIZIIIIII
# - 701.802 * ZIIIIIIIIIIIIIIIIIIIIIII
# - 195.0 * ZIIIIIIIIIIIIIIIIIIIZIII
# - 102.5 * ZIIIIIIIIIIIIIIIIIIIIZII
# - 97.5 * ZIIIIIIIIIIIIIIIIIIIZZII
# + 195.0 * ZIIIIIIIIIIIIIIIIIZIIIII
# + 102.5 * ZIIIIIIIIIIIIIIIIIIZIIII
# + 97.5 * ZIIIIIIIIIIIIIIIIIZZIIII
# - 200.0 * ZIIIIIIIIIIIIIIIZIIIIIII
# - 105.0 * ZIIIIIIIIIIIIIIIIZIIIIII
# - 100.0 * ZIIIIIIIIIIIIIIIZZIIIIII
# + 97.5 * ZIIIIIIIIIIIIIIIIIZIZIII
# - 100.0 * ZIIIIIIIIIIIIIIIZIIIZIII
# + 97.5 * ZIIIIIIIIIIIIIIIIIIZIZII
# - 100.0 * ZIIIIIIIIIIIIIIIIZIIIZII
# + 97.5 * ZIIIIIIIIIIIIIIIIIZZZZII
# - 100.0 * ZIIIIIIIIIIIIIIIZZIIZZII
# + 100.0 * ZIIIIIIIIIIIIIIIZIZIIIII
# + 100.0 * ZIIIIIIIIIIIIIIIIZIZIIII
# + 100.0 * ZIIIIIIIIIIIIIIIZZZZIIII
# + 97.5 * ZIIIIIIIIIIIIIIIIIIIIZIZ
# - 97.5 * ZIIIIIIIIIIIIIIIIIIIZZIZ
# - 97.5 * ZIIIIIIIIIIIIIIIIIIZIIIZ
# + 97.5 * ZIIIIIIIIIIIIIIIIIZZIIIZ
# + 100.0 * ZIIIIIIIIIIIIIIIIZIIIIIZ
# - 100.0 * ZIIIIIIIIIIIIIIIZZIIIIIZ
# + 5.0 * ZIIIIIIIIIIIIIIIIIIIIIIZ
# - 257.5 * IIIIIIIIZIIIIIIIIIIIIIII
# - 172.5 * IIIIIIIIZZIIIIIIIIIIIIII
# + 85.0 * IIIIIIIIIZIIIIIIIIIIIIIZ
# - 85.0 * IIIIIIIIZZIIIIIIIIIIIIIZ
# - 767.4085 * IIIZIIIIIIIIIIIIIIIIIIII
# - 250.0 * IIIZIIIIIIIIIIIIIIIIZIII
# - 167.5 * IIIZIIIIIIIIIIIIIIIIZZII
# + 257.5 * IIIZIIIIZIIIIIIIIIIIIIII
# + 172.5 * IIIZIIIIZZIIIIIIIIIIIIII
# + 85.0 * IIIZIIIIZIIIIIIIIIIIZIII
# + 85.0 * IIIZIIIIIZIIIIIIIIIIIZII
# + 85.0 * IIIZIIIIZZIIIIIIIIIIZZII
# - 170.0 * IIIZIIIIIIIIIIIIIIIIIIIZ
# + 82.5 * IIIZIIIIIIIIIIIIIIIIIZIZ
# - 82.5 * IIIZIIIIIIIIIIIIIIIIZZIZ
# - 85.0 * IIIZIIIIIZIIIIIIIIIIIIIZ
# + 85.0 * IIIZIIIIZZIIIIIIIIIIIIIZ
# + 2.5 * IIIIIIIIIZIIIIIIIIIIIIII
# + 2.5 * IIIZIIIIIIIIIIIIIIIIIZII
# - 2.5 * IIIZIIIIIZIIIIIIIIIIIIII
# + 160.0 * IIIIIIZIIIIIIIIIIIIIIIII
# + 85.0 * IIIIIIIZIIIIIIIIIIIIIIII
# + 80.0 * IIIIIIZZIIIIIIIIIIIIIIII
# + 80.0 * IIIIIIZIIIIIIIIIIIIIZIII
# + 80.0 * IIIIIIIZIIIIIIIIIIIIIZII
# + 80.0 * IIIIIIZZIIIIIIIIIIIIZZII
# - 80.0 * IIIIIIIZIIIIIIIIIIIIIIIZ
# + 80.0 * IIIIIIZZIIIIIIIIIIIIIIIZ
# - 579.7875 * IIZIIIIIIIIIIIIIIIIIIIII
# - 160.0 * IIZIIIIIIIIIIIIIIIIIZIII
# - 85.0 * IIZIIIIIIIIIIIIIIIIIIZII
# - 80.0 * IIZIIIIIIIIIIIIIIIIIZZII
# + 160.0 * IIZIIIIIIIIIIIIIIIZIIIII
# + 85.0 * IIZIIIIIIIIIIIIIIIIZIIII
# + 80.0 * IIZIIIIIIIIIIIIIIIZZIIII
# - 165.0 * IIZIIIZIIIIIIIIIIIIIIIII
# - 87.5 * IIZIIIIZIIIIIIIIIIIIIIII
# - 82.5 * IIZIIIZZIIIIIIIIIIIIIIII
# + 80.0 * IIZIIIIIIIIIIIIIIIZIZIII
# - 82.5 * IIZIIIZIIIIIIIIIIIIIZIII
# + 80.0 * IIZIIIIIIIIIIIIIIIIZIZII
# - 82.5 * IIZIIIIZIIIIIIIIIIIIIZII
# + 80.0 * IIZIIIIIIIIIIIIIIIZZZZII
# - 82.5 * IIZIIIZZIIIIIIIIIIIIZZII
# + 82.5 * IIZIIIZIIIIIIIIIIIZIIIII
# + 82.5 * IIZIIIIZIIIIIIIIIIIZIIII
# + 82.5 * IIZIIIZZIIIIIIIIIIZZIIII
# + 80.0 * IIZIIIIIIIIIIIIIIIIIIZIZ
# - 80.0 * IIZIIIIIIIIIIIIIIIIIZZIZ
# - 80.0 * IIZIIIIIIIIIIIIIIIIZIIIZ
# + 80.0 * IIZIIIIIIIIIIIIIIIZZIIIZ
# + 82.5 * IIZIIIIZIIIIIIIIIIIIIIIZ
# - 82.5 * IIZIIIZZIIIIIIIIIIIIIIIZ
# + 5.0 * IIZIIIIIIIIIIIIIIIIIIIIZ
# - 80.0 * IIIIIIIIIIIIIIZIIIIIZIII
# - 80.0 * IIIIIIIIIIIIIIIZIIIIIZII
# - 80.0 * IIIIIIIIIIIIIIZZIIIIZZII
# + 82.5 * IIIIIIIIIIIIIIZIIIZIIIII
# + 82.5 * IIIIIIIIIIIIIIIZIIIZIIII
# + 82.5 * IIIIIIIIIIIIIIZZIIZZIIII
# + 80.0 * IIIIIIIIIIIIIIIZIIIIIIIZ
# - 80.0 * IIIIIIIIIIIIIIZZIIIIIIIZ
# - 567.2875 * IIIIIZIIIIIIIIIIIIIIIIII
# - 155.0 * IIIIIZIIIIIIIIIIIIIIZIII
# - 77.5 * IIIIIZIIIIIIIIIIIIIIIZII
# - 77.5 * IIIIIZIIIIIIIIIIIIIIZZII
# + 160.0 * IIIIIZIIIIIIIIIIIIZIIIII
# + 80.0 * IIIIIZIIIIIIIIIIIIIZIIII
# + 80.0 * IIIIIZIIIIIIIIIIIIZZIIII
# + 160.0 * IIIIIZIIIIIIIIZIIIIIIIII
# + 80.0 * IIIIIZIIIIIIIIIZIIIIIIII
# + 80.0 * IIIIIZIIIIIIIIZZIIIIIIII
# + 80.0 * IIIIIZIIIIIIIIIIIIZIZIII
# + 80.0 * IIIIIZIIIIIIIIZIIIIIZIII
# + 80.0 * IIIIIZIIIIIIIIIIIIIZIZII
# + 80.0 * IIIIIZIIIIIIIIIZIIIIIZII
# + 80.0 * IIIIIZIIIIIIIIIIIIZZZZII
# + 80.0 * IIIIIZIIIIIIIIZZIIIIZZII
# - 82.5 * IIIIIZIIIIIIIIZIIIZIIIII
# - 82.5 * IIIIIZIIIIIIIIIZIIIZIIII
# - 82.5 * IIIIIZIIIIIIIIZZIIZZIIII
# + 77.5 * IIIIIZIIIIIIIIIIIIIIIZIZ
# - 77.5 * IIIIIZIIIIIIIIIIIIIIZZIZ
# - 80.0 * IIIIIZIIIIIIIIIIIIIZIIIZ
# + 80.0 * IIIIIZIIIIIIIIIIIIZZIIIZ
# - 80.0 * IIIIIZIIIIIIIIIZIIIIIIIZ
# + 80.0 * IIIIIZIIIIIIIIZZIIIIIIIZ
# + 2.5 * IIIIIIZIIIIIIIZIIIIIIIII
# + 2.5 * IIIIIIIZIIIIIIIZIIIIIIII
# + 2.5 * IIIIIIZZIIIIIIZZIIIIIIII
# + 5.0 * IIIIIZZIIIIIIIIIIIIIIIII
# + 2.5 * IIIIIZIZIIIIIIIIIIIIIIII
# + 2.5 * IIIIIZZZIIIIIIIIIIIIIIII
# + 2.5 * IIIIIZZIIIIIIIIIIIIIZIII
# + 2.5 * IIIIIZIZIIIIIIIIIIIIIZII
# + 2.5 * IIIIIZZZIIIIIIIIIIIIZZII
# - 2.5 * IIIIIZZIIIIIIIIIIIZIIIII
# - 2.5 * IIIIIZIZIIIIIIIIIIIZIIII
# - 2.5 * IIIIIZZZIIIIIIIIIIZZIIII
# - 2.5 * IIIIIZZIIIIIIIZIIIIIIIII
# - 2.5 * IIIIIZIZIIIIIIIZIIIIIIII
# - 2.5 * IIIIIZZZIIIIIIZZIIIIIIII
# - 2.5 * IIIIIZIZIIIIIIIIIIIIIIIZ
# + 2.5 * IIIIIZZZIIIIIIIIIIIIIIIZ
# + 2.5 * IIIIIIIIIIIIIIZIZIIIIIII
# + 2.5 * IIIIIIIIIIIIIIIZIZIIIIII
# + 2.5 * IIIIIIIIIIIIIIZZZZIIIIII
# + 5.0 * IIIIIZIIIIIIIIIIZIIIIIII
# + 2.5 * IIIIIZIIIIIIIIIIIZIIIIII
# + 2.5 * IIIIIZIIIIIIIIIIZZIIIIII
# + 2.5 * IIIIIZIIIIIIIIIIZIIIZIII
# + 2.5 * IIIIIZIIIIIIIIIIIZIIIZII
# + 2.5 * IIIIIZIIIIIIIIIIZZIIZZII
# - 2.5 * IIIIIZIIIIIIIIIIZIZIIIII
# - 2.5 * IIIIIZIIIIIIIIIIIZIZIIII
# - 2.5 * IIIIIZIIIIIIIIIIZZZZIIII
# - 2.5 * IIIIIZIIIIIIIIZIZIIIIIII
# - 2.5 * IIIIIZIIIIIIIIIZIZIIIIII
# - 2.5 * IIIIIZIIIIIIIIZZZZIIIIII
# - 2.5 * IIIIIZIIIIIIIIIIIZIIIIIZ
# + 2.5 * IIIIIZIIIIIIIIIIZZIIIIIZ
# + 85.0 * IIIIIIIIIIIIZIIIIIIIZIII
# + 85.0 * IIIIIIIIIIIIIZIIIIIIIZII
# + 85.0 * IIIIIIIIIIIIZZIIIIIIZZII
# - 85.0 * IIIIIIIIIIIIZIIIIIZIIIII
# - 85.0 * IIIIIIIIIIIIIZIIIIIZIIII
# - 85.0 * IIIIIIIIIIIIZZIIIIZZIIII
# + 87.5 * IIIIIIIIIIIIZIIIZIIIIIII
# + 87.5 * IIIIIIIIIIIIIZIIIZIIIIII
# + 87.5 * IIIIIIIIIIIIZZIIZZIIIIII
# - 514.842 * IIIIZIIIIIIIIIIIIIIIIIII
# - 82.5 * IIIIZIIIIIIIIIIIIIIIZIII
# + 82.5 * IIIIZIIIIIIIIIIIIIZIIIII
# - 85.0 * IIIIZIIIIIIIIIIIZIIIIIII
# - 85.0 * IIIIZIIIIIIIZIIIIIIIIIII
# + 82.5 * IIIIZIIIIIIIIIIIIIZIZIII
# - 85.0 * IIIIZIIIIIIIIIIIZIIIZIII
# - 85.0 * IIIIZIIIIIIIZIIIIIIIZIII
# + 82.5 * IIIIZIIIIIIIIIIIIIIZIZII
# - 85.0 * IIIIZIIIIIIIIIIIIZIIIZII
# - 85.0 * IIIIZIIIIIIIIZIIIIIIIZII
# + 82.5 * IIIIZIIIIIIIIIIIIIZZZZII
# - 85.0 * IIIIZIIIIIIIIIIIZZIIZZII
# - 85.0 * IIIIZIIIIIIIZZIIIIIIZZII
# + 85.0 * IIIIZIIIIIIIIIIIZIZIIIII
# + 85.0 * IIIIZIIIIIIIZIIIIIZIIIII
# + 85.0 * IIIIZIIIIIIIIIIIIZIZIIII
# + 85.0 * IIIIZIIIIIIIIZIIIIIZIIII
# + 85.0 * IIIIZIIIIIIIIIIIZZZZIIII
# + 85.0 * IIIIZIIIIIIIZZIIIIZZIIII
# - 87.5 * IIIIZIIIIIIIZIIIZIIIIIII
# - 87.5 * IIIIZIIIIIIIIZIIIZIIIIII
# - 87.5 * IIIIZIIIIIIIZZIIZZIIIIII
# + 82.5 * IIIIZIIIIIIIIIIIIIIIIZIZ
# - 82.5 * IIIIZIIIIIIIIIIIIIIIZZIZ
# - 82.5 * IIIIZIIIIIIIIIIIIIIZIIIZ
# + 82.5 * IIIIZIIIIIIIIIIIIIZZIIIZ
# + 85.0 * IIIIZIIIIIIIIIIIIZIIIIIZ
# - 85.0 * IIIIZIIIIIIIIIIIZZIIIIIZ
# + 85.0 * IIIIZIIIIIIIIZIIIIIIIIIZ
# - 85.0 * IIIIZIIIIIIIZZIIIIIIIIIZ

# %%
from qiskit.circuit.library import RealAmplitudes
from qiskit.algorithms.optimizers import COBYLA
from qiskit.algorithms import NumPyMinimumEigensolver
from qiskit.algorithms.minimum_eigensolvers import SamplingVQE
from qiskit import execute, Aer
from qiskit.primitives import Sampler

# set classical optimizer
optimizer = COBYLA(maxiter=50)

# set variational ansatz
ansatz = RealAmplitudes(reps=1)

counts = []
values = []


def store_intermediate_result(eval_count, parameters, mean, std):
    counts.append(eval_count)
    values.append(mean)


# initialize VQE using CVaR with alpha = 0.1
vqe = SamplingVQE(
    Sampler(),
    ansatz=ansatz,
    optimizer=optimizer,
    aggregation=0.1,
    callback=store_intermediate_result,
)

raw_result = vqe.compute_minimum_eigenvalue(qubit_op)
print(raw_result)
